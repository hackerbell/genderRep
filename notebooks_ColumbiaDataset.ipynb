# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.4.2

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     sep=<no_default>,
#     delimiter=None,
#     header='infer',
#     names=<no_default>,
#     index_col=None,
#     usecols=None,
#     squeeze=None,
#     prefix=<no_default>,
#     mangle_dupe_cols=True,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace=False,
#     skiprows=None,
#     skipfooter=0,
#     nrows=None,
#     na_values=None,
#     keep_default_na=True,
#     na_filter=True,
#     verbose=False,
#     skip_blank_lines=True,
#     parse_dates=None,
#     infer_datetime_format=False,
#     keep_date_col=False,
#     date_parser=None,
#     dayfirst=False,
#     cache_dates=True,
#     iterator=False,
#     chunksize=None,
#     compression: 'CompressionOptions' = 'infer',
#     thousands=None,
#     decimal: 'str' = '.',
# ...

# %%
df = pd.read_csv("characters.grivg.csv")

df.head(10)
# Out:
#           Name  Gender   Game       Age    Age_range  Playable  Sexualization  \
# 0        Farah  Female  CODMW        27        Adult         1              0
# 1  Protagonist  Custom    PSS  Teenager     Teenager         1              0
# 2     Magnolia  Female    PSS   Elderly      Elderly         0              0
# 3        Sonia  Female    PSS        26        Adult         0              0
# 4       Marnie  Female    PSS  Teenager     Teenager         0              0
# 5      Oleana   Female    PSS     Adult        Adult         0              0
# 6        Peach  Female    SMO     Adult        Adult         0              2
# 7        Zelda  Female   BOTW        17     Teenager         0              0
# 8  Protagonist  Custom    PSM        11        Child         1              0
# 9         Ciri  Female    TW3        21  Young adult         0              2
#
#                 Id Species Side Relevance Romantic_Interest
# ...

# %%
df = pd.read_csv("games.grivg.csv")

df.head(10)
# Out:
#   Game_Id                                    Title Release  \
# 0    GTAV                       Grand Theft Auto V  Nov-13
# 1     PSS                     Pokémon Sword/Shield  Nov-19
# 2   CODMW             Call of Duty: Modern Warfare  Oct-19
# 3    RDR2                    Red Dead Redemption 2  Dec-18
# 4     SMO                      Super Mario Odyssey  Oct-17
# 5    BOTW  The Legend of Zelda: Breath of the Wild  Mar-17
# 6     PSM                         Pokémon Sun/Moon  Nov-16
# 7     TW3                 The Witcher 3: Wild Hunt  May-15
# 8  CODBO2                Call of Duty: Black Ops 2  Nov-12
# 9     BL2                            Borderlands 2  Sep-12
#
#                 Series             Genre         Sub-genre         Developer  \
# 0                  GTA  Action-adventure  Action-adventure    Rockstar North
# 1              Pokémon               RPG               RPG        Game Freak
# 2         Call of Duty            Action               FPS     Infinity Ward
# ...
